# %%
import pandas as pd
import os
import numpy as np

# %%
#Import data
csv_path = "listings_2018_DataIssueCLean_15012021_JS.csv"
ListingsClean = pd.read_csv(csv_path, encoding="utf  -8")
ListingsClean.head()
#As per google - the messaged recieved indicates mixed datatypes in columns.
#You can set and action to turn this off - but I have fixed datatypes in this notebook
# Out:
# /Users/J/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       id     scrape_id last_scraped  \
# 0   9835  2.020000e+13      7/12/18
# 1  10803  2.020000e+13      7/12/18
# 2  12936  2.020000e+13      7/12/18
# 3  15246  2.020000e+13      7/12/18
# 4  16760  2.020000e+13      7/12/18
#
#                                                name  \
# 0                            Beautiful Room & House
# 1          Room in Cool Deco Apartment in Brunswick
# 2  St Kilda 1BR APT+BEACHSIDE+VIEWS+PARKING+WIFI+AC
# 3                  Large private room-close to city
# 4                  Melbourne BnB near City & Sports
#
#                                              summary  \
# 0                                                NaN
# ...

# %%
#view columns
print(ListingsClean.columns)
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'neighborhood_overview', 'transit', 'access', 'interaction', 'host_id',
#        'host_name', 'host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'street', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'city',
#        'state', 'zipcode', 'market', 'smart_location', 'country_code',
#        'country', 'latitude', 'longitude', 'is_location_exact',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'minimum_nights', 'maximum_nights', 'calendar_updated',
# ...

# %%
#I think we can drop these columns as irrelevant data: •D - I Listing profiles 
ListingCleanDrop1 = ListingsClean.drop(["name", "summary","neighborhood_overview","transit","access","interaction"], axis = 1)
ListingCleanDrop1.head()
# Out:
#       id     scrape_id last_scraped  host_id      host_name host_since  \
# 0   9835  2.020000e+13      7/12/18    33057          Manju    21/8/09
# 1  10803  2.020000e+13      7/12/18    38901        Lindsay    16/9/09
# 2  12936  2.020000e+13      7/12/18    50121  Frank & Vince   31/10/09
# 3  15246  2.020000e+13      7/12/18    59786          Eleni    3/12/09
# 4  16760  2.020000e+13      7/12/18    65090          Colin   22/12/09
#
#                            host_location  host_response_time  \
# 0                                     AU  a few days or more
# 1         Melbourne, Victoria, Australia                 NaN
# 2         Melbourne, Victoria, Australia      within an hour
# 3         Melbourne, Victoria, Australia                 NaN
# 4  Saint Kilda East, Victoria, Australia      within an hour
#
#   host_response_rate  host_acceptance_rate  ... first_review last_review  \
# 0                 0%                   NaN  ...      24/5/11     12/9/15
# ...

# %%
#I think we can drop these columns as irrelevant data: •L - P, T some host profiles
    #note removing host_listings_count as there is a host_total_listings_count in data
    #note neighbourhood removed as neighbourhood cleansed is correct data and blanks filled in.  and neighbourhood_group_cleansed is empty
    #square_feet mostly empty
ListingCleanDrop2 = ListingCleanDrop1.drop(['host_since', 'host_location', 
                                            'host_response_time', 'host_response_rate', 'host_acceptance_rate', 
                                            "host_listings_count", "host_neighbourhood", "neighbourhood", 
                                            "neighbourhood_group_cleansed", "market", 
                                            "is_location_exact", "calendar_updated",
                                           "first_review", "last_review", "square_feet"], axis = 1)
ListingCleanDrop2.head()
# Out:
#       id     scrape_id last_scraped  host_id      host_name host_is_superhost  \
# 0   9835  2.020000e+13      7/12/18    33057          Manju                 f
# 1  10803  2.020000e+13      7/12/18    38901        Lindsay                 f
# 2  12936  2.020000e+13      7/12/18    50121  Frank & Vince                 t
# 3  15246  2.020000e+13      7/12/18    59786          Eleni                 f
# 4  16760  2.020000e+13      7/12/18    65090          Colin                 f
#
#    host_total_listings_count                          street  \
# 0                        1.0         Bulleen, VIC, Australia
# 1                        1.0  Brunswick East, VIC, Australia
# 2                       17.0        St Kilda, VIC, Australia
# 3                        3.0       Thornbury, VIC, Australia
# 4                        1.0   St Kilda East, VIC, Australia
#
#   neighbourhood_cleansed            city  ... availability_365  \
# ...

# %%
#check columns
ListingCleanDrop2.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'host_id', 'host_name',
#        'host_is_superhost', 'host_total_listings_count', 'street',
#        'neighbourhood_cleansed', 'city', 'state', 'zipcode', 'smart_location',
#        'country_code', 'country', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'bed_type', 'amenities', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'reviews_per_month'],
#       dtype='object')

# %%
#Check data info for null fields
ListingCleanDrop2Info = ListingCleanDrop2.info()
ListingCleanDrop2Info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22895 entries, 0 to 22894
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           22895 non-null  int64
#  1   scrape_id                    22895 non-null  float64
#  2   last_scraped                 22895 non-null  object
#  3   host_id                      22895 non-null  int64
#  4   host_name                    22892 non-null  object
#  5   host_is_superhost            22892 non-null  object
#  6   host_total_listings_count    22892 non-null  float64
#  7   street                       22895 non-null  object
#  8   neighbourhood_cleansed       22895 non-null  object
#  9   city                         22872 non-null  object
#  10  state                        22834 non-null  object
#  11  zipcode                      22753 non-null  object
#  12  smart_location               22895 non-null  object
# ...

# %%
#Checking to see an eaxmple of a null field
ListingCleanDrop2[ListingCleanDrop2.id == 6147642]
# Out:
#            id     scrape_id last_scraped   host_id host_name  \
# 2248  6147642  2.020000e+13      7/12/18  31891911       NaN
#
#      host_is_superhost  host_total_listings_count                     street  \
# 2248               NaN                        NaN  Southbank, VIC, Australia
#
#      neighbourhood_cleansed       city  ... availability_365  \
# 2248              Melbourne  Southbank  ...                0
#
#      number_of_reviews review_scores_rating review_scores_accuracy  \
# 2248                 3                  NaN                    NaN
#
#      review_scores_cleanliness  review_scores_checkin  \
# 2248                       NaN                    NaN
#
#       review_scores_communication review_scores_location review_scores_value  \
# 2248                          NaN                    NaN                 NaN
#
#       reviews_per_month
# 2248               0.07
#
# [1 rows x 48 columns]

# %%
#Checking to see an eaxmple of a null field
ListingCleanDrop2[ListingCleanDrop2.id == 15000293]
# Out:
#             id     scrape_id last_scraped   host_id host_name  \
# 6957  15000293  2.020000e+13      7/12/18  50032978       NaN
#
#      host_is_superhost  host_total_listings_count               street  \
# 6957               NaN                        NaN  Kew, VIC, Australia
#
#      neighbourhood_cleansed city  ... availability_365 number_of_reviews  \
# 6957             Boroondara  Kew  ...              309                30
#
#      review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 6957                 97.0                   10.0                       9.0
#
#       review_scores_checkin  review_scores_communication  \
# 6957                   10.0                         10.0
#
#      review_scores_location review_scores_value  reviews_per_month
# 6957                   10.0                10.0               1.15
#
# [1 rows x 48 columns]

# %%
#Checking to see an eaxmple of a null field
ListingCleanDrop2[ListingCleanDrop2.id == 25766554]
# Out:
#              id     scrape_id last_scraped    host_id host_name  \
# 17765  25766554  2.020000e+13      7/12/18  193648165       NaN
#
#       host_is_superhost  host_total_listings_count                     street  \
# 17765               NaN                        NaN  Beaumaris, VIC, Australia
#
#       neighbourhood_cleansed       city  ... availability_365  \
# 17765                Bayside  Beaumaris  ...               88
#
#       number_of_reviews review_scores_rating review_scores_accuracy  \
# 17765                 1                  NaN                    NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 17765                       NaN                    NaN
#
#        review_scores_communication review_scores_location review_scores_value  \
# 17765                          NaN                    NaN                 NaN
#
#        reviews_per_month
# 17765               0.25
#
# [1 rows x 48 columns]

# %%
#TEST### - Fill NaN values for hostname with relevant value
ListingCleanDrop2['host_name'] = ListingCleanDrop2['host_name'].fillna("Missing")
#Check if filled the column
ListingCleanDrop2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22895 entries, 0 to 22894
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           22895 non-null  int64
#  1   scrape_id                    22895 non-null  float64
#  2   last_scraped                 22895 non-null  object
#  3   host_id                      22895 non-null  int64
#  4   host_name                    22895 non-null  object
#  5   host_is_superhost            22892 non-null  object
#  6   host_total_listings_count    22892 non-null  float64
#  7   street                       22895 non-null  object
#  8   neighbourhood_cleansed       22895 non-null  object
#  9   city                         22872 non-null  object
#  10  state                        22834 non-null  object
#  11  zipcode                      22753 non-null  object
#  12  smart_location               22895 non-null  object
# ...

# %%
#Checking to see if null field is now says "Missing" is host name
ListingCleanDrop2[ListingCleanDrop2.id == 6147642]
# Out:
#            id     scrape_id last_scraped   host_id host_name  \
# 2248  6147642  2.020000e+13      7/12/18  31891911   Missing
#
#      host_is_superhost  host_total_listings_count                     street  \
# 2248               NaN                        NaN  Southbank, VIC, Australia
#
#      neighbourhood_cleansed       city  ... availability_365  \
# 2248              Melbourne  Southbank  ...                0
#
#      number_of_reviews review_scores_rating review_scores_accuracy  \
# 2248                 3                  NaN                    NaN
#
#      review_scores_cleanliness  review_scores_checkin  \
# 2248                       NaN                    NaN
#
#       review_scores_communication review_scores_location review_scores_value  \
# 2248                          NaN                    NaN                 NaN
#
#       reviews_per_month
# 2248               0.07
#
# [1 rows x 48 columns]

# %%
#Actully need to drop columns that are completely empty first
ListingCleanDrop3 = ListingCleanDrop2.dropna(how='all', axis='columns')
ListingCleanDrop3
# Out:
#              id     scrape_id last_scraped    host_id      host_name  \
# 0          9835  2.020000e+13      7/12/18      33057          Manju
# 1         10803  2.020000e+13      7/12/18      38901        Lindsay
# 2         12936  2.020000e+13      7/12/18      50121  Frank & Vince
# 3         15246  2.020000e+13      7/12/18      59786          Eleni
# 4         16760  2.020000e+13      7/12/18      65090          Colin
# ...         ...           ...          ...        ...            ...
# 22890  30592332  2.020000e+13      7/12/18  229206629        Yolanda
# 22891  30592345  2.020000e+13      7/12/18  150660631  Mary And Lizz
# 22892  30592362  2.020000e+13      7/12/18  130394565            ç³
# 22893  30592590  2.020000e+13      7/12/18   22630928          Karin
# 22894  30593623  2.020000e+13      7/12/18   38305445           Nica
#
#       host_is_superhost  host_total_listings_count  \
# 0                     f                        1.0
# ...

# %%
#Drop rows with at least one empty value
ListingCleanDrop4 = ListingCleanDrop3.dropna()
len(ListingCleanDrop4)

#ISSUE*** - results in very few rows - DO NOT USE ListingCleanDrop4
# Out:
# 1119

# %%
# need to check data type in each column to assess how to handle null
    #(realised later that I could have run dtype command but actually looked at each column in csv)
    #Print columns with at least one empty value]
    #https://www.geeksforgeeks.org/working-with-missing-data-in-pandas/
    #https://stackoverflow.com/questions/43424199/display-rows-with-one-or-more-nan-values-in-pandas-dataframe
ListingCleanDrop3Missing = ListingCleanDrop3[ListingCleanDrop3.isna().any(axis=1)]

#Print column heading to then check how mimssing data from that column needs to be dealt with
ListingCleanDrop3Missing.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'host_id', 'host_name',
#        'host_is_superhost', 'host_total_listings_count', 'street',
#        'neighbourhood_cleansed', 'city', 'state', 'zipcode', 'smart_location',
#        'country_code', 'country', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'bed_type', 'amenities', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'reviews_per_month'],
#       dtype='object')

# %%
#Noticed ListingCleanDrop3[property_type] has more unique values that previously discuss. Pass this list on to Raph who is dropping out os scope data
ListingCleanDrop3.property_type.unique()
# Out:
# array(['House', 'Apartment', 'Loft', 'Townhouse', 'Hotel', 'Guesthouse',
#        'Guest suite', 'Farm stay', 'Condominium', 'Bed and breakfast',
#        'Serviced apartment', 'Cottage', 'Other', 'Boutique hotel',
#        'Earth house', 'Bungalow', 'Villa', 'Tiny house', 'Nature lodge',
#        'Cabin', 'Hostel', 'Barn', 'Train', 'Boat', 'Camper/RV',
#        'Campsite', 'Treehouse', 'Tent', 'Chalet', 'Aparthotel', 'Castle',
#        'Resort', 'Hut', 'Minsu (Taiwan)', 'Casa particular (Cuba)'],
#       dtype=object)

# %%
#Replace null (missing) value with relevant data
#https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html
#https://www.geeksforgeeks.org/replace-nan-values-with-zeros-in-pandas-dataframe/

#I want to start a new data frame - but when I use it to incorporate the action it only gives me one column?
#So simply renamed df
ListingCleanNulls = ListingCleanDrop2

#Fill NaN values with value "missing"
        #host_name
        #city = "missing"
ListingCleanNulls['host_name'] = ListingCleanDrop2['host_name'].fillna("Missing")
ListingCleanNulls['city'] = ListingCleanDrop2['city'].fillna("Missing")

#Fill NaN values with value "f"
        #host_is_superhost
ListingCleanNulls['host_is_superhost'] = ListingCleanDrop2['host_is_superhost'].fillna("f")
    
#Fill NaN values with value "0"
        #host_total_listings_count
        #bathrooms
        #bedrooms', 'beds'
        #square_feet
        #price', 'weekly_price', monthly_price'
        #'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people'
        #number_of_reviews
        #review_scores_rating',
        #   'review_scores_accuracy', 'review_scores_cleanliness',
        #   'review_scores_checkin', 'review_scores_communication',
        #   'review_scores_location', 'review_scores_value', 'reviews_per_month'
ListingCleanNulls['host_total_listings_count'] = ListingCleanNulls['host_total_listings_count'].fillna("0")

ListingCleanNulls['bathrooms'] = ListingCleanNulls['bathrooms'].fillna("0")

ListingCleanNulls['bedrooms'] = ListingCleanNulls['bedrooms'].fillna("0")

ListingCleanNulls['beds'] = ListingCleanNulls['beds'].fillna("0")

ListingCleanNulls['price'] = ListingCleanNulls['price'].fillna("0")

ListingCleanNulls['weekly_price'] = ListingCleanNulls['weekly_price'].fillna("0")

ListingCleanNulls['monthly_price'] = ListingCleanNulls['monthly_price'].fillna("0")

ListingCleanNulls['security_deposit'] = ListingCleanNulls['security_deposit'].fillna("0")

ListingCleanNulls['cleaning_fee'] = ListingCleanNulls['cleaning_fee'].fillna("0")

ListingCleanNulls['guests_included'] = ListingCleanNulls['guests_included'].fillna("0")

ListingCleanNulls['extra_people'] = ListingCleanNulls['extra_people'].fillna("0")

ListingCleanNulls['number_of_reviews'] = ListingCleanNulls['number_of_reviews'].fillna("0")

ListingCleanNulls['review_scores_rating'] = ListingCleanNulls['review_scores_rating'].fillna("0")

ListingCleanNulls['review_scores_accuracy'] = ListingCleanNulls['review_scores_accuracy'].fillna("0")

ListingCleanNulls['review_scores_cleanliness'] = ListingCleanNulls['review_scores_cleanliness'].fillna("0")

ListingCleanNulls['review_scores_checkin'] = ListingCleanNulls['review_scores_checkin'].fillna("0")

ListingCleanNulls['review_scores_communication'] = ListingCleanNulls['review_scores_communication'].fillna("0")

ListingCleanNulls['review_scores_location'] = ListingCleanNulls['review_scores_location'].fillna("0")

ListingCleanNulls['review_scores_value'] = ListingCleanNulls['review_scores_value'].fillna("0")

ListingCleanNulls['reviews_per_month'] = ListingCleanNulls['reviews_per_month'].fillna("0")


#Fill NaN values with value "Victoria"
        #State
ListingCleanNulls['state'] = ListingCleanNulls['state'].fillna("0")

#Fill NaN values with value "0000" - CONVERT ALL TO STRING? - dtype('O') - a type of string so I think ok.
        #zipcode = "0000" = CONVERT ALL TO STING?
ListingCleanNulls['zipcode'] = ListingCleanNulls['zipcode'].fillna("0000")
    
    
    
#ListingCleanNulls
#ListingCleanNulls.info()
#ListingCleanNulls["host_name"]=='Manju')
#ListingCleanDrop2[ListingCleanDrop2.host_name == "Manju"]
#ListingCleanNulls[ListingCleanDrop2.id == 6147642]
#ListingCleanNulls.info()

#Check if columns are all now filled
ListingCleanNulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22895 entries, 0 to 22894
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           22895 non-null  int64
#  1   scrape_id                    22895 non-null  float64
#  2   last_scraped                 22895 non-null  object
#  3   host_id                      22895 non-null  int64
#  4   host_name                    22895 non-null  object
#  5   host_is_superhost            22895 non-null  object
#  6   host_total_listings_count    22895 non-null  object
#  7   street                       22895 non-null  object
#  8   neighbourhood_cleansed       22895 non-null  object
#  9   city                         22895 non-null  object
#  10  state                        22895 non-null  object
#  11  zipcode                      22895 non-null  object
#  12  smart_location               22895 non-null  object
# ...

# %%
# one missing values is cast to floating-point dtype for whole column
#-so once fixed missing values re-check data types
# - the followng columns have incorrect dtypes

ListingCleanDTypes = ListingCleanNulls

    #Should be floats (decimals)
        #20  bathrooms object
        #21  bedrooms  object
        #22  beds       object 
        #48  reviews_per_month  object
#df['DataFrame Column'] = df['DataFrame Column'].astype(float)
ListingCleanDTypes['bathrooms'] = ListingCleanDTypes['bathrooms'].astype(float)

ListingCleanDTypes['bedrooms'] = ListingCleanDTypes['bedrooms'].astype(float)

ListingCleanDTypes['beds'] = ListingCleanDTypes['beds'].astype(float)

ListingCleanDTypes['reviews_per_month'] = ListingCleanDTypes['reviews_per_month'].astype(float)

#Check this first lot of data type changes worked
ListingCleanDTypes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22895 entries, 0 to 22894
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           22895 non-null  int64
#  1   scrape_id                    22895 non-null  float64
#  2   last_scraped                 22895 non-null  object
#  3   host_id                      22895 non-null  int64
#  4   host_name                    22895 non-null  object
#  5   host_is_superhost            22895 non-null  object
#  6   host_total_listings_count    22895 non-null  object
#  7   street                       22895 non-null  object
#  8   neighbourhood_cleansed       22895 non-null  object
#  9   city                         22895 non-null  object
#  10  state                        22895 non-null  object
#  11  zipcode                      22895 non-null  object
#  12  smart_location               22895 non-null  object
# ...

# %%
#Checking look at dtype of price column
ListingCleanDTypes[ListingCleanDTypes.id == 12719024]["price"]
# Out:
# 5636    $12,624.00
# Name: price, dtype: object

# %%
#Converting currency string to float (decimal)
#https://pbpython.com/pandas_dtypes.html

#Function to strip dollar signs and comma and change to float - don't quite understand but works!!
def convert_currency(val):
    """
    Convert the string number value to a float
     - Remove $
     - Remove commas
     - Convert to float type
    """
    new_val = val.replace(',','').replace('$', '')
    return float(new_val)

# %%
#Test function on price column
ListingCleanDTypes['price'] = ListingCleanDTypes['price'].apply(convert_currency)
ListingCleanDTypes
# Out:
#              id     scrape_id last_scraped    host_id      host_name  \
# 0          9835  2.020000e+13      7/12/18      33057          Manju
# 1         10803  2.020000e+13      7/12/18      38901        Lindsay
# 2         12936  2.020000e+13      7/12/18      50121  Frank & Vince
# 3         15246  2.020000e+13      7/12/18      59786          Eleni
# 4         16760  2.020000e+13      7/12/18      65090          Colin
# ...         ...           ...          ...        ...            ...
# 22890  30592332  2.020000e+13      7/12/18  229206629        Yolanda
# 22891  30592345  2.020000e+13      7/12/18  150660631  Mary And Lizz
# 22892  30592362  2.020000e+13      7/12/18  130394565            ç³
# 22893  30592590  2.020000e+13      7/12/18   22630928          Karin
# 22894  30593623  2.020000e+13      7/12/18   38305445           Nica
#
#       host_is_superhost host_total_listings_count  \
# 0                     f                         1
# ...

# %%
#Checking look at dtype of price column to conversion to float has worked
ListingCleanDTypes[ListingCleanDTypes.id == 12719024]["price"]
# Out:
# 5636    12624.0
# Name: price, dtype: float64

# %%
#Complete converstion of rest of currency columns
ListingCleanDTypes['weekly_price'] = ListingCleanDTypes['weekly_price'].apply(convert_currency)
ListingCleanDTypes['monthly_price'] = ListingCleanDTypes['monthly_price'].apply(convert_currency)
ListingCleanDTypes['security_deposit'] = ListingCleanDTypes['security_deposit'].apply(convert_currency)
ListingCleanDTypes['cleaning_fee'] = ListingCleanDTypes['cleaning_fee'].apply(convert_currency)
ListingCleanDTypes['extra_people'] = ListingCleanDTypes['extra_people'].apply(convert_currency)
ListingCleanDTypes
# Out:
#              id     scrape_id last_scraped    host_id      host_name  \
# 0          9835  2.020000e+13      7/12/18      33057          Manju
# 1         10803  2.020000e+13      7/12/18      38901        Lindsay
# 2         12936  2.020000e+13      7/12/18      50121  Frank & Vince
# 3         15246  2.020000e+13      7/12/18      59786          Eleni
# 4         16760  2.020000e+13      7/12/18      65090          Colin
# ...         ...           ...          ...        ...            ...
# 22890  30592332  2.020000e+13      7/12/18  229206629        Yolanda
# 22891  30592345  2.020000e+13      7/12/18  150660631  Mary And Lizz
# 22892  30592362  2.020000e+13      7/12/18  130394565            ç³
# 22893  30592590  2.020000e+13      7/12/18   22630928          Karin
# 22894  30593623  2.020000e+13      7/12/18   38305445           Nica
#
#       host_is_superhost host_total_listings_count  \
# 0                     f                         1
# ...

# %%
ListingCleanDTypes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22895 entries, 0 to 22894
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           22895 non-null  int64
#  1   scrape_id                    22895 non-null  float64
#  2   last_scraped                 22895 non-null  object
#  3   host_id                      22895 non-null  int64
#  4   host_name                    22895 non-null  object
#  5   host_is_superhost            22895 non-null  object
#  6   host_total_listings_count    22895 non-null  object
#  7   street                       22895 non-null  object
#  8   neighbourhood_cleansed       22895 non-null  object
#  9   city                         22895 non-null  object
#  10  state                        22895 non-null  object
#  11  zipcode                      22895 non-null  object
#  12  smart_location               22895 non-null  object
# ...

# %%
 #Should be integer (whole number)
        #41  review_scores_rating  object 
        #42  review_scores_accuracy  object 
        #43  review_scores_cleanliness  object 
        #44  review_scores_checkin  object 
        #45  review_scores_communication  object 
        #46  review_scores_location  object 
        #47  review_scores_value  object 
ListingCleanDTypes['host_total_listings_count'] = ListingCleanDTypes['host_total_listings_count'].astype(int)
ListingCleanDTypes['review_scores_rating'] = ListingCleanDTypes['review_scores_rating'].astype(int)
ListingCleanDTypes['review_scores_accuracy'] = ListingCleanDTypes['review_scores_accuracy'].astype(int)
ListingCleanDTypes['review_scores_cleanliness'] = ListingCleanDTypes['review_scores_cleanliness'].astype(int)
ListingCleanDTypes['review_scores_checkin'] = ListingCleanDTypes['review_scores_rating'].astype(int)
ListingCleanDTypes['review_scores_communication'] = ListingCleanDTypes['review_scores_communication'].astype(int)
ListingCleanDTypes['review_scores_location'] = ListingCleanDTypes['review_scores_location'].astype(int)
ListingCleanDTypes['review_scores_value'] = ListingCleanDTypes['review_scores_value'].astype(int)
ListingCleanDTypes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22895 entries, 0 to 22894
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           22895 non-null  int64
#  1   scrape_id                    22895 non-null  float64
#  2   last_scraped                 22895 non-null  object
#  3   host_id                      22895 non-null  int64
#  4   host_name                    22895 non-null  object
#  5   host_is_superhost            22895 non-null  object
#  6   host_total_listings_count    22895 non-null  int64
#  7   street                       22895 non-null  object
#  8   neighbourhood_cleansed       22895 non-null  object
#  9   city                         22895 non-null  object
#  10  state                        22895 non-null  object
#  11  zipcode                      22895 non-null  object
#  12  smart_location               22895 non-null  object
# ...

# %%
# - checkeing for values issues for relevant columns
a = ListingCleanDTypes["host_is_superhost"].unique()
a.sort()
print (a)
print("")
b = ListingCleanDTypes["neighbourhood_cleansed"].unique()
b.sort()
print (b)
print("")
c = ListingCleanDTypes["city"].unique()
c.sort()
print (c)
print("")
d = ListingCleanDTypes["smart_location"].unique()
d.sort()
print (d)
print("")
e = ListingCleanDTypes["country_code"].unique()
e.sort()
print (e)
print("")
f = ListingCleanDTypes["country"].unique()
f.sort()
print (f)
print("")
g = ListingCleanDTypes["has_availability"].unique()
g.sort()
print (g)
print("")

#checking with team if “city” or “smart_location” - all else are good
# Out:
# ['f' 't']
#
# ['Banyule' 'Bayside' 'Boroondara' 'Brimbank' 'Cardinia' 'Casey' 'Darebin'
#  'Frankston' 'Glen Eira' 'Greater Dandenong' 'Hobsons Bay' 'Hume'
#  'Kingston' 'Knox' 'Manningham' 'Maribyrnong' 'Maroondah' 'Melbourne'
#  'Melton' 'Monash' 'Moonee Valley' 'Moreland' 'Nillumbik' 'Port Phillip'
#  'Stonnington' 'Whitehorse' 'Whittlesea' 'Wyndham' 'Yarra' 'Yarra Ranges']
#
# [' Melbourne' ' South Yarra' 'Abbotsford' 'Abbotsford '
#  'Abbotsford, Melbourne' 'Aberfeldie' 'Airport West' 'Albanvale'
#  'Albert Park' 'Albert Park. Melbourne ' 'Albion' 'Alphington' 'Altona'
#  'Altona Meadows' 'Altona North' 'Armadale' 'Armadale North' 'Ascot Vale'
#  'Ashburton' 'Ashwood' 'Aspendale' 'Aspendale Gardens' 'Attwood'
#  'Avondale Heights' 'BRUNSWICK EAST' 'Badger Creek' 'Balaclava' 'Balwyn'
#  'Balwyn North' 'Bangholme' 'Bayles' 'Bayswater' 'Bayswater North'
#  'Beaconsfield' 'Beaconsfield Upper' 'Beaumaris' 'Belgrave'
# ...

# %%
#strip leading and trailing space

 

ListingCleanDTypes['city'] = ListingCleanDTypes['city'].str.strip()
ListingCleanDTypes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22895 entries, 0 to 22894
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           22895 non-null  int64
#  1   scrape_id                    22895 non-null  float64
#  2   last_scraped                 22895 non-null  object
#  3   host_id                      22895 non-null  int64
#  4   host_name                    22895 non-null  object
#  5   host_is_superhost            22895 non-null  object
#  6   host_total_listings_count    22895 non-null  int64
#  7   street                       22895 non-null  object
#  8   neighbourhood_cleansed       22895 non-null  object
#  9   city                         22895 non-null  object
#  10  state                        22895 non-null  object
#  11  zipcode                      22895 non-null  object
#  12  smart_location               22895 non-null  object
# ...

# %%
print("")
c = ListingCleanDTypes["city"].unique()
c.sort()
print (c)
# Out:
# ['Abbotsford' 'Abbotsford, Melbourne' 'Aberfeldie' 'Airport West'
#  'Albanvale' 'Albert Park' 'Albert Park. Melbourne' 'Albion' 'Alphington'
#  'Altona' 'Altona Meadows' 'Altona North' 'Armadale' 'Armadale North'
#  'Ascot Vale' 'Ashburton' 'Ashwood' 'Aspendale' 'Aspendale Gardens'
#  'Attwood' 'Avondale Heights' 'BRUNSWICK EAST' 'Badger Creek' 'Balaclava'
#  'Balwyn' 'Balwyn North' 'Bangholme' 'Bayles' 'Bayswater'
#  'Bayswater North' 'Beaconsfield' 'Beaconsfield Upper' 'Beaumaris'
#  'Belgrave' 'Belgrave Heights' 'Bellfield' 'Bentleigh' 'Bentleigh East'
#  'Berwick' 'Beveridge' 'Big Pats Creek' 'Black Rock' 'Blackburn'
#  'Blackburn North' 'Blackburn South' 'Bonbeach' 'Boronia' 'Botanic Ridge'
#  'Box Hill' 'Box Hill North' 'Box Hill South' 'Braybrook' 'Briar Hill'
#  'Brighton' 'Brighton East' 'Brighton East, Melbourne' 'Brimbank City'
#  'Brisbane' 'Broadmeadows' 'Brookfield' 'Brooklyn' 'Brunswick'
#  'Brunswick / Melbourne' 'Brunswick East' 'Brunswick East, Melbourne'
# ...

# %%
ListingCleanDrop2[ListingCleanDrop2.city == "City of Port Phillip"]
# Out:
#             id     scrape_id last_scraped   host_id host_name  \
# 4872  11192596  2.020000e+13      7/12/18  58275305      Brad
#
#      host_is_superhost  host_total_listings_count  \
# 4872                 f                          1
#
#                                     street neighbourhood_cleansed  \
# 4872  City of Port Phillip, VIC, Australia           Port Phillip
#
#                       city  ... availability_365 number_of_reviews  \
# 4872  City of Port Phillip  ...              327                 7
#
#      review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 4872                   97                     10                         9
#
#       review_scores_checkin  review_scores_communication  \
# 4872                     97                           10
#
#      review_scores_location review_scores_value  reviews_per_month
# 4872                     10                  10               0.22
#
# [1 rows x 48 columns]

# %%
ListingCleanDrop2[ListingCleanDrop2.city == "VIC"]
# Out:
#              id     scrape_id last_scraped    host_id host_name  \
# 11534  20401547  2.020000e+13      7/12/18  130415824       Lyn
# 14959  22841285  2.020000e+13      7/12/18  130415824       Lyn
# 14960  22841579  2.020000e+13      7/12/18  130415824       Lyn
# 22174  30238833  2.020000e+13      7/12/18  130415824       Lyn
#
#       host_is_superhost  host_total_listings_count               street  \
# 11534                 f                         14  VIC, VIC, Australia
# 14959                 f                         14  VIC, VIC, Australia
# 14960                 f                         14  VIC, VIC, Australia
# 22174                 f                         14  VIC, VIC, Australia
#
#       neighbourhood_cleansed city  ... availability_365 number_of_reviews  \
# 11534              Melbourne  VIC  ...              298                22
# 14959              Melbourne  VIC  ...              298                 7
# ...

# %%
ListingCleanDrop2[ListingCleanDrop2.city == "å¢¨çˆ¾æœ¬ Melbourne"]
# Out:
#              id     scrape_id last_scraped    host_id host_name  \
# 11645  20527741  2.020000e+13      7/12/18  146552336    Melody
#
#       host_is_superhost  host_total_listings_count  \
# 11645                 f                          2
#
#                                                  street  \
# 11645  å¢¨çˆ¾æœ¬ Melbourne, ç¶­å¤šåˆ©äºž VIC, Australia
#
#       neighbourhood_cleansed                 city  ... availability_365  \
# 11645              Melbourne  å¢¨çˆ¾æœ¬ Melbourne  ...               48
#
#       number_of_reviews review_scores_rating review_scores_accuracy  \
# 11645                23                   96                     10
#
#       review_scores_cleanliness  review_scores_checkin  \
# 11645                        10                     96
#
#        review_scores_communication review_scores_location review_scores_value  \
# 11645                           10                     10                  10
#
#        reviews_per_month
# ...

# %%
'å¢¨å°”æœ¬'
ListingCleanDrop2[ListingCleanDrop2.city == "å¢¨å°”æœ¬"]
# Out:
#              id     scrape_id last_scraped    host_id host_name  \
# 1165    3658967  2.020000e+13      7/12/18   18541709     Jason
# 7272   15516535  2.020000e+13      7/12/18   81743692     Zhang
# 8670   16870277  2.020000e+13      7/12/18  112427684        Su
# 18884  27338685  2.020000e+13      7/12/18  192203819   Rebecca
# 19697  28270692  2.020000e+13      7/12/18  202392882       ç‘›
#
#       host_is_superhost  host_total_listings_count  \
# 1165                  f                          1
# 7272                  f                          3
# 8670                  f                          1
# 18884                 f                          1
# 19697                 f                          1
#
#                                       street neighbourhood_cleansed  \
# 1165   å¢¨å°”æœ¬, ç»´å¤šåˆ©äºšå·ž, Australia             Manningham
# 7272      å¢¨å°”æœ¬, ç»´å¤šåˆ©äºš, Australia             Manningham
# ...

# %%
ListingCleanDrop2[ListingCleanDrop2.city == "èŠ’ç‰¹éŸ¦å¼—åˆ©åŒº"]
# Out:
#           id     scrape_id last_scraped  host_id  host_name host_is_superhost  \
# 873  2622804  2.020000e+13      7/12/18  9610062  Catherine                 f
#
#      host_total_listings_count                              street  \
# 873                          1  èŠ’ç‰¹éŸ¦å¼—åˆ©åŒº, VIC, Australia
#
#     neighbourhood_cleansed                city  ... availability_365  \
# 873                 Monash  èŠ’ç‰¹éŸ¦å¼—åˆ©åŒº  ...              123
#
#     number_of_reviews review_scores_rating review_scores_accuracy  \
# 873                 1                   80                     10
#
#     review_scores_cleanliness  review_scores_checkin  \
# 873                        10                     80
#
#      review_scores_communication review_scores_location review_scores_value  \
# 873                           10                     10                  10
#
#      reviews_per_month
# 873               0.02
#
# [1 rows x 48 columns]

# %%
ListingCleanDTypes
# Out:
#              id     scrape_id last_scraped    host_id      host_name  \
# 0          9835  2.020000e+13      7/12/18      33057          Manju
# 1         10803  2.020000e+13      7/12/18      38901        Lindsay
# 2         12936  2.020000e+13      7/12/18      50121  Frank & Vince
# 3         15246  2.020000e+13      7/12/18      59786          Eleni
# 4         16760  2.020000e+13      7/12/18      65090          Colin
# ...         ...           ...          ...        ...            ...
# 22890  30592332  2.020000e+13      7/12/18  229206629        Yolanda
# 22891  30592345  2.020000e+13      7/12/18  150660631  Mary And Lizz
# 22892  30592362  2.020000e+13      7/12/18  130394565            ç³
# 22893  30592590  2.020000e+13      7/12/18   22630928          Karin
# 22894  30593623  2.020000e+13      7/12/18   38305445           Nica
#
#       host_is_superhost  host_total_listings_count  \
# 0                     f                          1
# ...

# %%
#Fix spelling mistake
#titanic["Sex_short"] = titanic["Sex"].replace({"male": "M", "female": "F"})
ListingCleanDTypes["city"] = ListingCleanDTypes["city"].replace({"Abbotsford, Melbourne":"Abbotsford"})
print("")
c = ListingCleanDTypes["city"].unique()
c.sort()
print (c)
# Out:
# ['Abbotsford' 'Aberfeldie' 'Airport West' 'Albanvale' 'Albert Park'
#  'Albert Park. Melbourne' 'Albion' 'Alphington' 'Altona' 'Altona Meadows'
#  'Altona North' 'Armadale' 'Armadale North' 'Ascot Vale' 'Ashburton'
#  'Ashwood' 'Aspendale' 'Aspendale Gardens' 'Attwood' 'Avondale Heights'
#  'BRUNSWICK EAST' 'Badger Creek' 'Balaclava' 'Balwyn' 'Balwyn North'
#  'Bangholme' 'Bayles' 'Bayswater' 'Bayswater North' 'Beaconsfield'
#  'Beaconsfield Upper' 'Beaumaris' 'Belgrave' 'Belgrave Heights'
#  'Bellfield' 'Bentleigh' 'Bentleigh East' 'Berwick' 'Beveridge'
#  'Big Pats Creek' 'Black Rock' 'Blackburn' 'Blackburn North'
#  'Blackburn South' 'Bonbeach' 'Boronia' 'Botanic Ridge' 'Box Hill'
#  'Box Hill North' 'Box Hill South' 'Braybrook' 'Briar Hill' 'Brighton'
#  'Brighton East' 'Brighton East, Melbourne' 'Brimbank City' 'Brisbane'
#  'Broadmeadows' 'Brookfield' 'Brooklyn' 'Brunswick'
#  'Brunswick / Melbourne' 'Brunswick East' 'Brunswick East, Melbourne'
# ...

# %%
#ListingCleanDTypes["city"] = ListingCleanDTypes["city"].replace({"Abbotsford, Melbourne":"Abbotsford","Albert Park. Melbourne":"Albert Park","BRUNSWICK EAST":"Brunswick East,","Brunswick / Melbourne":"Brunswick","Brunswick East, Melbourne":"Brunswick East","Brunswick VIC 3056":"Brunswick","Brunswick West, Melbourne":"Brunswick West","Brunswick west":"Brunswick West","Carlton, Melbourne":"Carlton","Chum Creek/Healesville":"Chum Creek","Coburg (Melbourne)":"Coburg","Collingwood, Melbourne":"Collingwood","Dockland ":"Docklands","Doncaster VIC 3108":"Doncaster","Doncasterï¼Œmelbourne":"Doncaster","East st kilda ":"East St Kilda","Elwood, Melbourne":"Elwood","Elwood, St. Kilda":"Elwood","Elwood, St. Kilda ":"Elwood","Essendon, Victoria, AU":"Essendon","FITZROY":"Fitzroy","Fitzroy, Melbourne":"Fitzroy","Fitzroy, Victoria, AU":"Fitzroy","Glen Iris, Victoria, AU":"Glen Iris","HEIDELBERG":"Heidelberg","HEIDELBERG WEST":"Heidelberg West","Hawthorn east":"Hawthorn East","Hawthorn, Melbourne":"Hawthorn","Ivanhoe (Melbourne)":"Ivanhoe","Kangaroo ground":"Kangaroo Ground'","Kew East, Victoria, AU":"Kew East","Malvern, Melbourne":"Malvern","Maribyrnong, Melbourne":"Maribyrnong","Mcmahons Creek":"McMahons Creek","Melborne":"Melbourne","Melbourne (Eltham)":"Eltham","Melbourne CBD":"Melbourne","Melbourne City":"Melbourne","Melbourne VIC 3000":"Melbourne","Melbourne VIC 3004":"Melbourne","Melbourne Victoria":"Melbourne","Melbourne, Victoria, AU":"Melbourne","Melton South ( STRATHTULLOH)":"Strathtulloh ","Middle Park Melbourne":"Middle Park","Mlebourne":"Melbourne","North Melbourne, Victoria, AU":"North Melbourne","Northcote South":"Northcote","Northcote, Victoria, AU":"Northcote","Oaklands junction ":"Oaklands Junction","Prahran / Toorak ":"Prahran","Richmond, Victoria, AU":"Richmond","Ripponlea (East St Kilda)":"Ripponlea","STRATHTULLOH":"Strathtulloh","STRTHTULLOCH":"Strathtulloh","Saint Kilda Beach":"St Kilda","Saint Kilda":"St Kilda","Saint Kilda East'":"St Kilda East","Saint Kilda West":"St Kilda West","Saint Kilda, Victoria, AU":"St Kilda","South Melbourne, Melbourne":"South Melbourne","South Yarra VIC 3141":"South Yarra","South Yarra, Victoria, AU":"South Yarra","Southbank, Melbourne":"Southbank","Southbank, Victoria, AU":"Southbank","St Kilda / Elwood":"Elwood","St Kilda West Melbourne":"St Kilda West","St Kilda east":"St Kilda East","St kilda":"St Kilda","St kilda ":"St Kilda","St. Andrews":"St Andrews","St. Kilda":"St Kilda","St. Kilda West":"St Kilda West","St.Kilda East":"St Kilda East","StKilda East":"St Kilda East","Surrey Hills, Victoria, AU":"Surrey Hills","Thornbury, Victoria, AU":"Thornbury","Toorak, Melbourne.":"Toorak","Truganina ":"Truganina","Truganina, Victoria, AU":"Truganina","VIC":"Melbourne","Victoria":"Melbourne","Wantirna South VIC 3152":"Wantirna South ","Wantirna south":"Wantirna South ","Wesburn,10minutes to Warburton":"Wesburn","West Melbourne - flagstaff ":"West Melbourne ","Wheelers Hill VIC 3150":"Wheelers Hill ","Yarra Glen, Victoria, AU":"Yarra Glen,","Yarra Valley, Yarra Glen, Healesville":"Yarra Valley","Yellingbo, Yarra Valley":"Yellingbo","brunswick":"Brunswick","clayton":"Clayton","clayton south":"Clayton South","melbourne":"Melbourne","st kilda":"St Kilda","å¢¨çˆ¾æœ¬ Melbourne":"Melbourne"})
#ListingCleanDTypes["city"] = ListingCleanDTypes["city"].replace({"Abbotsford, Melbourne":"Abbotsford","Albert Park. Melbourne":"Albert Park","BRUNSWICK EAST":"Brunswick East,","Brunswick / Melbourne":"Brunswick","Brunswick East, Melbourne":"Brunswick East","Brunswick VIC 3056":"Brunswick","Brunswick West, Melbourne":"Brunswick West","Brunswick west":"Brunswick West","Carlton, Melbourne":"Carlton","Chum Creek/Healesville":"Chum Creek","Coburg (Melbourne)":"Coburg","Collingwood, Melbourne":"Collingwood","Dockland ":"Docklands","Doncaster VIC 3108":"Doncaster","Doncasterï¼Œmelbourne":"Doncaster","East st kilda ":"East St Kilda","Elwood, Melbourne":"Elwood","Elwood, St. Kilda":"Elwood","Elwood, St. Kilda ":"Elwood","Essendon, Victoria, AU":"Essendon","FITZROY":"Fitzroy","Fitzroy, Melbourne":"Fitzroy","Fitzroy, Victoria, AU":"Fitzroy","Glen Iris, Victoria, AU":"Glen Iris","HEIDELBERG":"Heidelberg","HEIDELBERG WEST":"Heidelberg West","Hawthorn east":"Hawthorn East","Hawthorn, Melbourne":"Hawthorn","Ivanhoe (Melbourne)":"Ivanhoe","Kangaroo ground":"Kangaroo Ground'","Kew East, Victoria, AU":"Kew East","Malvern, Melbourne":"Malvern","Maribyrnong, Melbourne":"Maribyrnong","Mcmahons Creek":"McMahons Creek","Melborne":"Melbourne","Melbourne (Eltham)":"Eltham","Melbourne CBD":"Melbourne","Melbourne City":"Melbourne","Melbourne VIC 3000":"Melbourne","Melbourne VIC 3004":"Melbourne","Melbourne Victoria":"Melbourne","Melbourne, Victoria, AU":"Melbourne","Melton South ( STRATHTULLOH)":"Strathtulloh ","Middle Park Melbourne":"Middle Park","Mlebourne":"Melbourne"})
#ListingCleanDTypes["city"] = ListingCleanDTypes["city"].replace({"Abbotsford, Melbourne":"Abbotsford","Albert Park. Melbourne":"Albert Park","BRUNSWICK EAST":"Brunswick East,","Brunswick / Melbourne":"Brunswick","Brunswick East, Melbourne":"Brunswick East","Brunswick VIC 3056":"Brunswick","Brunswick West, Melbourne":"Brunswick West","Brunswick west":"Brunswick West","Carlton, Melbourne":"Carlton","Chum Creek/Healesville":"Chum Creek","Coburg (Melbourne)":"Coburg","Collingwood, Melbourne":"Collingwood","Dockland ":"Docklands","Doncaster VIC 3108":"Doncaster","Doncasterï¼Œmelbourne":"Doncaster","East st kilda ":"East St Kilda","Elwood, Melbourne":"Elwood","Elwood, St. Kilda":"Elwood","Elwood, St. Kilda ":"Elwood","Essendon, Victoria, AU":"Essendon","FITZROY":"Fitzroy","Fitzroy, Melbourne":"Fitzroy","Fitzroy, Victoria, AU":"Fitzroy","Glen Iris, Victoria, AU":"Glen Iris","HEIDELBERG":"Heidelberg","HEIDELBERG WEST":"Heidelberg West","Hawthorn east":"Hawthorn East","Hawthorn, Melbourne":"Hawthorn","Ivanhoe (Melbourne)":"Ivanhoe","Kangaroo ground":"Kangaroo Ground'","Kew East, Victoria, AU":"Kew East","Malvern, Melbourne":"Malvern","Maribyrnong, Melbourne":"Maribyrnong","Mcmahons Creek":"McMahons Creek","Melborne":"Melbourne","Melbourne (Eltham)":"Eltham","Melbourne CBD":"Melbourne","Melbourne City":"Melbourne","Melbourne VIC 3000":"Melbourne","Melbourne VIC 3004":"Melbourne","Melbourne Victoria":"Melbourne","Melbourne, Victoria, AU":"Melbourne","Melton South ( STRATHTULLOH)":"Strathtulloh ","Middle Park Melbourne":"Middle Park","Mlebourne":"Melbourne","North Melbourne, Victoria, AU":"North Melbourne","Northcote South":"Northcote","Northcote, Victoria, AU":"Northcote","Oaklands junction ":"Oaklands Junction","Prahran / Toorak ":"Prahran","Richmond, Victoria, AU":"Richmond","Ripponlea (East St Kilda)":"Ripponlea","STRATHTULLOH":"Strathtulloh","STRTHTULLOCH":"Strathtulloh","Saint Kilda Beach":"St Kilda","Saint Kilda":"St Kilda","Saint Kilda East'":"St Kilda East","Saint Kilda West":"St Kilda West","Saint Kilda, Victoria, AU":"St Kilda","South Melbourne, Melbourne":"South Melbourne","South Yarra VIC 3141":"South Yarra","South Yarra, Victoria, AU":"South Yarra","Southbank, Melbourne":"Southbank","Southbank, Victoria, AU":"Southbank","St Kilda / Elwood":"Elwood","St Kilda West Melbourne":"St Kilda West","St Kilda east":"St Kilda East","St kilda":"St Kilda","St kilda ":"St Kilda","St. Andrews":"St Andrews"})
ListingCleanDTypes["city"] = ListingCleanDTypes["city"].replace({"Abbotsford, Melbourne":"Abbotsford","Albert Park. Melbourne":"Albert Park","BRUNSWICK EAST":"Brunswick East,","Brunswick / Melbourne":"Brunswick","Brunswick East, Melbourne":"Brunswick East","Brunswick VIC 3056":"Brunswick","Brunswick West, Melbourne":"Brunswick West","Brunswick west":"Brunswick West","Carlton, Melbourne":"Carlton","Chum Creek/Healesville":"Chum Creek","Coburg (Melbourne)":"Coburg","Collingwood, Melbourne":"Collingwood","Dockland ":"Docklands","Doncaster VIC 3108":"Doncaster","Doncasterï¼Œmelbourne":"Doncaster","East st kilda ":"East St Kilda","Elwood, Melbourne":"Elwood","Elwood, St. Kilda":"Elwood","Elwood, St. Kilda ":"Elwood","Essendon, Victoria, AU":"Essendon","FITZROY":"Fitzroy","Fitzroy, Melbourne":"Fitzroy","Fitzroy, Victoria, AU":"Fitzroy","Glen Iris, Victoria, AU":"Glen Iris","HEIDELBERG":"Heidelberg","HEIDELBERG WEST":"Heidelberg West","Hawthorn east":"Hawthorn East","Hawthorn, Melbourne":"Hawthorn","Ivanhoe (Melbourne)":"Ivanhoe","Kangaroo ground":"Kangaroo Ground'","Kew East, Victoria, AU":"Kew East","Malvern, Melbourne":"Malvern","Maribyrnong, Melbourne":"Maribyrnong","Mcmahons Creek":"McMahons Creek","Melborne":"Melbourne","Melbourne (Eltham)":"Eltham","Melbourne CBD":"Melbourne","Melbourne City":"Melbourne","Melbourne VIC 3000":"Melbourne","Melbourne VIC 3004":"Melbourne","Melbourne Victoria":"Melbourne","Melbourne, Victoria, AU":"Melbourne","Melton South ( STRATHTULLOH)":"Strathtulloh ","Middle Park Melbourne":"Middle Park","Mlebourne":"Melbourne","North Melbourne, Victoria, AU":"North Melbourne","Northcote South":"Northcote","Northcote, Victoria, AU":"Northcote","Oaklands junction ":"Oaklands Junction","Prahran / Toorak ":"Prahran","Richmond, Victoria, AU":"Richmond","Ripponlea (East St Kilda)":"Ripponlea","STRATHTULLOH":"Strathtulloh","STRTHTULLOCH":"Strathtulloh","Saint Kilda Beach":"St Kilda","Saint Kilda":"St Kilda","Saint Kilda East'":"St Kilda East","Saint Kilda West":"St Kilda West","Saint Kilda, Victoria, AU":"St Kilda","South Melbourne, Melbourne":"South Melbourne","South Yarra VIC 3141":"South Yarra","South Yarra, Victoria, AU":"South Yarra","Southbank, Melbourne":"Southbank","Southbank, Victoria, AU":"Southbank","St Kilda / Elwood":"Elwood","St Kilda West Melbourne":"St Kilda West","St Kilda east":"St Kilda East","St kilda":"St Kilda","St kilda ":"St Kilda","St. Andrews":"St Andrews","St. Kilda":"St Kilda","St. Kilda West":"St Kilda West","St.Kilda East":"St Kilda East","StKilda East":"St Kilda East","Surrey Hills, Victoria, AU":"Surrey Hills","Thornbury, Victoria, AU":"Thornbury","Toorak, Melbourne.":"Toorak","Truganina ":"Truganina","Truganina, Victoria, AU":"Truganina","VIC":"Melbourne","Victoria":"Melbourne","Wantirna South VIC 3152":"Wantirna South ","Wantirna south":"Wantirna South ","Wesburn,10minutes to Warburton":"Wesburn","West Melbourne - flagstaff ":"West Melbourne ","Wheelers Hill VIC 3150":"Wheelers Hill ","Yarra Glen, Victoria, AU":"Yarra Glen,","Yarra Valley, Yarra Glen, Healesville":"Yarra Valley","Yellingbo, Yarra Valley":"Yellingbo","brunswick":"Brunswick","clayton":"Clayton","clayton south":"Clayton South","melbourne":"Melbourne","st kilda":"St Kilda","å¢¨çˆ¾æœ¬ Melbourne":"Melbourne"})
ListingCleanDTypes
# Out:
#              id     scrape_id last_scraped    host_id      host_name  \
# 0          9835  2.020000e+13      7/12/18      33057          Manju
# 1         10803  2.020000e+13      7/12/18      38901        Lindsay
# 2         12936  2.020000e+13      7/12/18      50121  Frank & Vince
# 3         15246  2.020000e+13      7/12/18      59786          Eleni
# 4         16760  2.020000e+13      7/12/18      65090          Colin
# ...         ...           ...          ...        ...            ...
# 22890  30592332  2.020000e+13      7/12/18  229206629        Yolanda
# 22891  30592345  2.020000e+13      7/12/18  150660631  Mary And Lizz
# 22892  30592362  2.020000e+13      7/12/18  130394565            ç³
# 22893  30592590  2.020000e+13      7/12/18   22630928          Karin
# 22894  30593623  2.020000e+13      7/12/18   38305445           Nica
#
#       host_is_superhost  host_total_listings_count  \
# 0                     f                          1
# ...

# %%
ListingCleanDTypes["city"]
# Out:
# 0               Bulleen
# 1        Brunswick East
# 2              St Kilda
# 3             Thornbury
# 4         St Kilda East
#               ...
# 22890           Carlton
# 22891      Melton South
# 22892     Glen Waverley
# 22893         Southbank
# 22894           Carlton
# Name: city, Length: 22895, dtype: object

# %%
blah = ListingCleanDTypes["city"].unique()
blah.sort()
print (blah)
# Out:
# ['Abbotsford' 'Aberfeldie' 'Airport West' 'Albanvale' 'Albert Park'
#  'Albion' 'Alphington' 'Altona' 'Altona Meadows' 'Altona North' 'Armadale'
#  'Armadale North' 'Ascot Vale' 'Ashburton' 'Ashwood' 'Aspendale'
#  'Aspendale Gardens' 'Attwood' 'Avondale Heights' 'Badger Creek'
#  'Balaclava' 'Balwyn' 'Balwyn North' 'Bangholme' 'Bayles' 'Bayswater'
#  'Bayswater North' 'Beaconsfield' 'Beaconsfield Upper' 'Beaumaris'
#  'Belgrave' 'Belgrave Heights' 'Bellfield' 'Bentleigh' 'Bentleigh East'
#  'Berwick' 'Beveridge' 'Big Pats Creek' 'Black Rock' 'Blackburn'
#  'Blackburn North' 'Blackburn South' 'Bonbeach' 'Boronia' 'Botanic Ridge'
#  'Box Hill' 'Box Hill North' 'Box Hill South' 'Braybrook' 'Briar Hill'
#  'Brighton' 'Brighton East' 'Brighton East, Melbourne' 'Brimbank City'
#  'Brisbane' 'Broadmeadows' 'Brookfield' 'Brooklyn' 'Brunswick'
#  'Brunswick East' 'Brunswick East,' 'Brunswick West' 'Bulla' 'Bulleen'
#  'Bundoora' 'Bunyip' 'Burnley' 'Burnside' 'Burnside Heights' 'Burwood'
# ...

# %%
#Still got issues
#'Brighton East, Melbourne'
#'Dandenong Ranges'
#'Dockland'
#'Doncasterï¼ŒMelbourne'
#'East St. Kilda'
# 'East st kilda'
#Kangaroo Ground'
#'Oaklands junction'
#Prahran / Toorak'
#'Saint Kilda East'
#'Somerton VIC 3062'
#'Southbank Melbourne'
#'Strathtulloh '
#'Wantirna South '
#'West Melbourne - flagstaff'
#'Wheelers Hill '
#'eaglemont'

#Need to delete
'å¢¨å°”æœ¬'
 'èŠ’ç‰¹éŸ¦å¼—åˆ©åŒº'
