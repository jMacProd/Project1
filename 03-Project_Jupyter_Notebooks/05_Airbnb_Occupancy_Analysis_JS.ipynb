# %% [markdown]
# DESCRIPTION:
# The highest occupancy rates are in the following neighbourhoods.
# The highest earners are in the following neighbourhoods
# Is there a correlation? Are high occupancies the highest earners
#
# Which neighbourhoods indicate highest occupancy?
#
# Considerations
# Distance from CBD?
# Listing
# areas
# occupancy
# Average occupancy for that neighbou
# Top 10
# Bottom 10
# Bar chart – top 10 bottom10
# Average stay overall
#
# #######DO correlation coefficient with other question's data

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as dta
#For correlation coefficient
import scipy.stats as st

# %%
#Read in csv file

CSV_path = "../02-Data_Files_Directory/02-Clean_Data/airbnbFINAL_JS.csv"

airbnbOccStart = pd.read_csv(CSV_path)
airbnbOccStart
# Out:
#             id    host_id      host_name host_is_superhost  \
# 0        12936      50121  Frank & Vince                 t
# 1        47100     212071          Loren                 t
# 2        50492      50121  Frank & Vince                 t
# 3        51592     190879       Michelle                 t
# 4        66754      50121  Frank & Vince                 t
# ...        ...        ...            ...               ...
# 9885  30410904  127327853         Nathan                 f
# 9886  30468406   30322920          Robyn                 f
# 9887  30470482   36410227        Sabrina                 f
# 9888  30483362  154023219         Aishah                 f
# 9889  30490522   12676584            Eli                 f
#
#       host_total_listings_count                          street  \
# 0                            17        St Kilda, VIC, Australia
# 1                             4        Richmond, VIC, Australia
# 2                            17        St Kilda, VIC, Australia
# 3                             1       Melbourne, VIC, Australia
# 4                            17        Richmond, VIC, Australia
# ...                         ...                             ...
# 9885                          1       Melbourne, VIC, Australia
# 9886                          1  Brunswick West, VIC, Australia
# 9887                        276       Port Melbourne, Australia
# 9888                          1         Preston, VIC, Australia
# 9889                          1        Richmond, VIC, Australia
#
#      neighbourhood_cleansed            city state zipcode  ...  \
# 0              Port Phillip        St Kilda   Vic    3182  ...
# 1                     Yarra        Richmond   Vic    3121  ...
# 2              Port Phillip        St Kilda   Vic    3182  ...
# 3                 Melbourne       Melbourne   Vic    3000  ...
# 4                     Yarra        Richmond   Vic    3121  ...
# ...                     ...             ...   ...     ...  ...
# 9885              Melbourne       Melbourne   Vic    3000  ...
# 9886               Moreland  Brunswick West   Vic    3055  ...
# 9887           Port Phillip  Port Melbourne   Vic    3207  ...
# 9888                Darebin         Preston   Vic    3072  ...
# 9889                  Yarra        Richmond   Vic    3121  ...
#
#       number_of_reviews  review_scores_rating review_scores_accuracy  \
# 0                    15                    94                      9
# 1                   176                    98                     10
# 2                    44                    97                     10
# 3                   196                    99                     10
# 4                    43                    95                      9
# ...                 ...                   ...                    ...
# 9885                  2                   100                     10
# 9886                  1                     0                      0
# 9887                  1                     0                      0
# 9888                  1                     0                      0
# 9889                  1                     0                      0
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                            10                     94
# 1                            10                     98
# 2                            10                     97
# 3                             9                     99
# 4                            10                     95
# ...                         ...                    ...
# 9885                         10                    100
# 9886                          0                      0
# 9887                          0                      0
# 9888                          0                      0
# 9889                          0                      0
#
#       review_scores_communication  review_scores_location review_scores_value  \
# 0                               9                       9                   9
# 1                              10                      10                  10
# 2                              10                       9                  10
# 3                              10                      10                  10
# 4                              10                      10                   9
# ...                           ...                     ...                 ...
# 9885                           10                      10                  10
# 9886                            0                       0                   0
# 9887                            0                       0                   0
# 9888                            0                       0                   0
# 9889                            0                       0                   0
#
#      reviews_per_month  distance_from_cbd
# 0                 0.15           5.205174
# 1                 1.75           3.649571
# 2                 0.60           5.437003
# 3                 2.07           0.072335
# 4                 0.46           2.794548
# ...                ...                ...
# 9885              2.00           0.700146
# 9886              1.00           5.893982
# 9887              1.00           3.780995
# 9888              1.00           8.746854
# 9889              1.00           3.648557
#
# [9890 rows x 43 columns]

# %%
#List of columns
airbnbOccStart.columns
# Out:
# Index(['id', 'host_id', 'host_name', 'host_is_superhost',
#        'host_total_listings_count', 'street', 'neighbourhood_cleansed', 'city',
#        'state', 'zipcode', 'latitude', 'longitude', 'property_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'amenities', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'reviews_per_month',
#        'distance_from_cbd'],
#       dtype='object')

# %%
# Checking the number of records.
    #number of unique neighbourhoods

print("There are " + str(len(airbnbOccStart)) + " records in the dataframe")
    

print("There are " + str(len(airbnbOccStart["neighbourhood_cleansed"].unique())) +  " unique neighbourhoods in the dataframe")
# Out:
# There are 9890 records in the dataframe
# There are 14 unique neighbourhoods in the dataframe

# %%
#determine if blank fields and datatypes
airbnbOccStart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9890 entries, 0 to 9889
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           9890 non-null   int64
#  1   host_id                      9890 non-null   int64
#  2   host_name                    9890 non-null   object
#  3   host_is_superhost            9890 non-null   object
#  4   host_total_listings_count    9890 non-null   int64
#  5   street                       9890 non-null   object
#  6   neighbourhood_cleansed       9890 non-null   object
#  7   city                         9890 non-null   object
#  8   state                        9890 non-null   object
#  9   zipcode                      9890 non-null   object
#  10  latitude                     9890 non-null   float64
#  11  longitude                    9890 non-null   float64
#  12  property_type                9890 non-null   object
#  13  accommodates                 9890 non-null   int64
#  14  bathrooms                    9890 non-null   float64
#  15  bedrooms                     9890 non-null   float64
#  16  beds                         9890 non-null   float64
#  17  bed_type                     9890 non-null   object
#  18  amenities                    9890 non-null   object
#  19  price                        9890 non-null   float64
#  20  weekly_price                 9890 non-null   float64
#  21  monthly_price                9890 non-null   float64
#  22  security_deposit             9890 non-null   float64
#  23  cleaning_fee                 9890 non-null   float64
#  24  guests_included              9890 non-null   int64
#  25  extra_people                 9890 non-null   float64
#  26  minimum_nights               9890 non-null   int64
#  27  maximum_nights               9890 non-null   int64
#  28  has_availability             9890 non-null   object
#  29  availability_30              9890 non-null   int64
#  30  availability_60              9890 non-null   int64
#  31  availability_90              9890 non-null   int64
#  32  availability_365             9890 non-null   int64
#  33  number_of_reviews            9890 non-null   int64
#  34  review_scores_rating         9890 non-null   int64
#  35  review_scores_accuracy       9890 non-null   int64
#  36  review_scores_cleanliness    9890 non-null   int64
#  37  review_scores_checkin        9890 non-null   int64
#  38  review_scores_communication  9890 non-null   int64
#  39  review_scores_location       9890 non-null   int64
#  40  review_scores_value          9890 non-null   int64
#  41  reviews_per_month            9890 non-null   float64
#  42  distance_from_cbd            9890 non-null   float64
# dtypes: float64(13), int64(19), object(11)
# memory usage: 3.2+ MB

# %% [markdown]
# ### Neighbourhood Summary Table
# Based on average reviews per month

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM 
    #of the rating for each Neighbourhood

# This method produces everything in a single groupby function
airbnbOccNeighGroup = airbnbOccStart.groupby(["neighbourhood_cleansed"])
airbnbOccsummary = airbnbOccNeighGroup["reviews_per_month"].agg(["mean", "median", "var", "std", "sem"])
airbnbOccsummarysort = airbnbOccsummary.sort_values(by="mean", ascending=False) 

airbnb_Occupancy_Rate_Summary = airbnbOccsummarysort.rename(columns={
    "mean":"Mean reviews per month",
    "median":"Median reviews per month",
    "var":"Variance reviews per month",
    "std":"Standard Deviation reviews per month",
    "sem":"SEM reviews per month"
})

airbnb_Occupancy_Rate_Summary
# Out:
#                         Mean reviews per month  Median reviews per month  \
# neighbourhood_cleansed
# Melbourne                             2.393162                     1.900
# Brimbank                              2.228000                     2.410
# Moonee Valley                         1.718417                     1.145
# Yarra                                 1.514548                     0.990
# Banyule                               1.498462                     1.030
# Maribyrnong                           1.492618                     1.130
# Boroondara                            1.447131                     0.955
# Port Phillip                          1.327065                     0.780
# Moreland                              1.304704                     0.700
# Hobsons Bay                           1.254024                     0.930
# Stonnington                           1.230101                     0.700
# Bayside                               1.116552                     0.660
# Darebin                               1.018076                     0.490
# Glen Eira                             0.968564                     0.570
#
#                         Variance reviews per month  \
# neighbourhood_cleansed
# Melbourne                                 4.111560
# Brimbank                                  0.093620
# Moonee Valley                             2.872543
# Yarra                                     2.540386
# Banyule                                   1.984363
# Maribyrnong                               1.897380
# Boroondara                                2.465908
# Port Phillip                              2.201566
# Moreland                                  2.357639
# Hobsons Bay                               1.958217
# Stonnington                               1.984412
# Bayside                                   1.379205
# Darebin                                   1.765034
# Glen Eira                                 0.921283
#
#                         Standard Deviation reviews per month  \
# neighbourhood_cleansed
# Melbourne                                           2.027698
# Brimbank                                            0.305974
# Moonee Valley                                       1.694858
# Yarra                                               1.593859
# Banyule                                             1.408674
# Maribyrnong                                         1.377454
# Boroondara                                          1.570321
# Port Phillip                                        1.483767
# Moreland                                            1.535461
# Hobsons Bay                                         1.399363
# Stonnington                                         1.408692
# Bayside                                             1.174396
# Darebin                                             1.328546
# Glen Eira                                           0.959835
#
#                         SEM reviews per month
# neighbourhood_cleansed
# Melbourne                            0.030120
# Brimbank                             0.136836
# Moonee Valley                        0.154719
# Yarra                                0.047000
# Banyule                              0.174725
# Maribyrnong                          0.099669
# Boroondara                           0.100529
# Port Phillip                         0.036018
# Moreland                             0.079610
# Hobsons Bay                          0.154534
# Stonnington                          0.047087
# Bayside                              0.154206
# Darebin                              0.077881
# Glen Eira                            0.070003

# %% [markdown]
# #### Neighbourhood Summary Table Observation
# Stand outs are Melbourne and Brimbank with a similar mean
# However Melbourne's median  differs from its mean and the variance is  large compared to the Brimbank.
# Brimbank's standard deviation is also substantially lower than Melbourne.
# Due to Melbourne's unpredictability, and the rest of the neighbourhoods being somewhat consistent Mean, it is benefical to break it down into cities (suburbs)

# %% [markdown]
# ### City Summary Table Top 10
# Based on average reviews per month

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM 
    #of the rating for each city

# This method produces everything in a single groupby function
airbnbOccCityGroup = airbnbOccStart.groupby(["city"])
airbnbOccCitysummary = airbnbOccCityGroup["reviews_per_month"].agg(["mean", "median", "var", "std", "sem"])

airbnbOccCitysummary = airbnbOccCitysummary.rename(columns={
    "mean":"Mean reviews per month",
    "median":"Median reviews per month",
    "var":"Variance reviews per month",
    "std":"Standard Deviation reviews per month",
    "sem":"SEM reviews per month"
})

airbnbOccCitysummarysorttop = airbnbOccCitysummary.sort_values(by = "Mean reviews per month", ascending=False)


airbnb_Occupancy_City_Rate_Summary_TopTen = airbnbOccCitysummarysorttop.head(10)

airbnb_Occupancy_City_Rate_Summary_TopTen
# Out:
#                     Mean reviews per month  Median reviews per month  \
# city
# Niddrie                           8.520000                     8.520
# Brooklyn                          7.830000                     7.830
# Essendon North                    3.020000                     3.020
# Strathmore                        2.933333                     3.630
# Melbourne                         2.567119                     2.070
# Docklands                         2.378560                     1.605
# Maribyrnong                       2.320000                     2.255
# West Melbourne                    2.308889                     2.000
# Heidelberg Heights                2.301250                     2.235
# Moonee Ponds                      2.292727                     1.630
#
#                     Variance reviews per month  \
# city
# Niddrie                                    NaN
# Brooklyn                                   NaN
# Essendon North                             NaN
# Strathmore                            4.965033
# Melbourne                             4.232003
# Docklands                             5.252441
# Maribyrnong                           2.748680
# West Melbourne                        2.989962
# Heidelberg Heights                    4.226927
# Moonee Ponds                          3.790954
#
#                     Standard Deviation reviews per month  \
# city
# Niddrie                                              NaN
# Brooklyn                                             NaN
# Essendon North                                       NaN
# Strathmore                                      2.228235
# Melbourne                                       2.057183
# Docklands                                       2.291820
# Maribyrnong                                     1.657914
# West Melbourne                                  1.729151
# Heidelberg Heights                              2.055949
# Moonee Ponds                                    1.947037
#
#                     SEM reviews per month
# city
# Niddrie                               NaN
# Brooklyn                              NaN
# Essendon North                        NaN
# Strathmore                       1.286472
# Melbourne                        0.038677
# Docklands                        0.117260
# Maribyrnong                      0.325144
# West Melbourne                   0.144096
# Heidelberg Heights               0.726888
# Moonee Ponds                     0.415110

# %% [markdown]
# ### City Summary Table Bottom 10
# Based on average reviews per month

# %%
airbnbOccCitysummarysortbottom = airbnbOccCitysummary.sort_values(by = "Mean reviews per month", ascending=True)

airbnb_Occupancy_City_Rate_Summary_BottomTen = airbnbOccCitysummarysortbottom.head(10)

airbnb_Occupancy_City_Rate_Summary_BottomTen
# Out:
#                       Mean reviews per month  Median reviews per month  \
# city
# Port Phillip City                   0.090000                      0.09
# Preston West                        0.100000                      0.10
# City of Port Phillip                0.220000                      0.22
# Essendon West                       0.240000                      0.24
# Gardenvale                          0.337500                      0.29
# Moreland City                       0.420000                      0.42
# Ashburton                           0.450000                      0.45
# Altona North                        0.497143                      0.32
# South Kingsville                    0.581667                      0.38
# Middle Park                         0.630303                      0.43
#
#                       Variance reviews per month  \
# city
# Port Phillip City                            NaN
# Preston West                                 NaN
# City of Port Phillip                         NaN
# Essendon West                                NaN
# Gardenvale                              0.091292
# Moreland City                                NaN
# Ashburton                               0.217800
# Altona North                            0.180857
# South Kingsville                        0.332817
# Middle Park                             0.315041
#
#                       Standard Deviation reviews per month  \
# city
# Port Phillip City                                      NaN
# Preston West                                           NaN
# City of Port Phillip                                   NaN
# Essendon West                                          NaN
# Gardenvale                                        0.302145
# Moreland City                                          NaN
# Ashburton                                         0.466690
# Altona North                                      0.425273
# South Kingsville                                  0.576903
# Middle Park                                       0.561285
#
#                       SEM reviews per month
# city
# Port Phillip City                       NaN
# Preston West                            NaN
# City of Port Phillip                    NaN
# Essendon West                           NaN
# Gardenvale                         0.151073
# Moreland City                           NaN
# Ashburton                          0.330000
# Altona North                       0.160738
# South Kingsville                   0.235520
# Middle Park                        0.097707

# %%
#checking which neighbourhoods for the top and bottom 10 cities

# iterating the columns 
for row in airbnb_Occupancy_City_Rate_Summary_TopTen.index: 
     
    neighbourhood = airbnbOccStart[airbnbOccStart.city == row]["neighbourhood_cleansed"]
       
    print("The top suburb of " + row + " is in the neighbourhood of " + neighbourhood.iloc[0])

    
    
print("")
# iterating the columns 
for row in airbnb_Occupancy_City_Rate_Summary_BottomTen.index: 
     
    neighbourhood = airbnbOccStart[airbnbOccStart.city == row]["neighbourhood_cleansed"]
       
    print("The bottom suburb of " + row + " is in the neighbourhood of " + neighbourhood.iloc[0])
# Out:
# The top suburb of Niddrie is in the neighbourhood of Moonee Valley
# The top suburb of Brooklyn is in the neighbourhood of Hobsons Bay
# The top suburb of Essendon North is in the neighbourhood of Moonee Valley
# The top suburb of Strathmore is in the neighbourhood of Moonee Valley
# The top suburb of Melbourne is in the neighbourhood of Melbourne
# The top suburb of Docklands is in the neighbourhood of Melbourne
# The top suburb of Maribyrnong is in the neighbourhood of Maribyrnong
# The top suburb of West Melbourne is in the neighbourhood of Melbourne
# The top suburb of Heidelberg Heights is in the neighbourhood of Banyule
# The top suburb of Moonee Ponds is in the neighbourhood of Moonee Valley
#
# The bottom suburb of Port Phillip City is in the neighbourhood of Port Phillip
# The bottom suburb of Preston West is in the neighbourhood of Darebin
# The bottom suburb of City of Port Phillip is in the neighbourhood of Port Phillip
# The bottom suburb of Essendon West is in the neighbourhood of Moonee Valley
# The bottom suburb of Gardenvale is in the neighbourhood of Glen Eira
# The bottom suburb of Moreland City is in the neighbourhood of Moreland
# The bottom suburb of Ashburton is in the neighbourhood of Boroondara
# The bottom suburb of Altona North is in the neighbourhood of Hobsons Bay
# The bottom suburb of South Kingsville is in the neighbourhood of Hobsons Bay
# The bottom suburb of Middle Park is in the neighbourhood of Port Phillip

# %% [markdown]
# #### City Summary Table Observation
# Where as the summary table indicated Melbourne and Brimbank as the top 2 neighbourhoods, by ranking occupancy we can see the following:
# * Melbourne has 3 suburbs in the top ten suburbs
# * But Moonee Valley also has 4 suburbs.

# %% [markdown]
# ### Bar plot of total number of reviews

# %%
#To get a sense ofhow this occupany rate might look for a a year, extrapolate monthly reviews over 12 months

#Top cities
BarchartseriesTop = airbnb_Occupancy_City_Rate_Summary_TopTen["Mean reviews per month"] * 12

#Create Y axis values
topy = pd.Series(BarchartseriesTop).values
print(topy)

#Create x 
topx = BarchartseriesTop.index
print(topx)
# Out:
# [102.24        93.96        36.24        35.2         30.80542948
#   28.54272251  27.84        27.70666667  27.615       27.51272727]
# Index(['Niddrie', 'Brooklyn', 'Essendon North', 'Strathmore', 'Melbourne',
#        'Docklands', 'Maribyrnong', 'West Melbourne', 'Heidelberg Heights',
#        'Moonee Ponds'],
#       dtype='object', name='city')

# %%
#Bottom cities
BarchartseriesBottom = airbnb_Occupancy_City_Rate_Summary_BottomTen["Mean reviews per month"] * 12
BarchartseriesBottomSort = BarchartseriesBottom.sort_values(ascending=False)
BarchartseriesBottomSort

#Create Y axis values
bottomy = pd.Series(BarchartseriesBottomSort).values
print(bottomy)

#Create x 
bottomx = BarchartseriesBottomSort.index
print(bottomx)
# Out:
# [7.56363636 6.98       5.96571429 5.4        5.04       4.05
#  2.88       2.64       1.2        1.08      ]
# Index(['Middle Park', 'South Kingsville', 'Altona North', 'Ashburton',
#        'Moreland City', 'Gardenvale', 'Essendon West', 'City of Port Phillip',
#        'Preston West', 'Port Phillip City'],
#       dtype='object', name='city')

# %%
#TOP bar chart

plt.figure(figsize=(12,6))
plt.bar(topx, topy, width=.5,)
plt.title('Projected number of reviews over 12 months for the top ten cities')
plt.xlabel('Top ten cities',fontdict={'fontsize':12})
plt.ylabel('Number of reivews', fontdict={'fontsize':12})

plt.show()

# %%
#BOTTOM bar chart

plt.figure(figsize=(12,6))
plt.bar(bottomx, bottomy, width=.5,)
plt.title('Projected number of reviews over 12 months for the bottom ten cities')
plt.xlabel('Bottom ten cities',fontdict={'fontsize':12})
plt.ylabel('Number of reivews', fontdict={'fontsize':12})

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,6), sharey=True)


fig.suptitle('Projected number of reviews over 12 months for the top and bottom ten cities')


ax1.bar(topx, topy)

for ax in fig.axes:
    ax.tick_params(labelrotation=45)


ax2.bar(bottomx, bottomy)
# Out:
# <BarContainer object of 10 artists>

# %%
#Generate a pie plot to see the break up of accomodation types
airbnbpropertygroup = airbnbOccStart.groupby(["property_type"])
airbnbpropertycount = airbnbpropertygroup["id"].nunique()

airbnbpropertycount.plot.pie(title='Distribution of property type', autopct="%1.1f%%")
plt.ylabel('')
plt.legend()
